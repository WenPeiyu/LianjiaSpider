# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns
path = r"E:\wenpeiyu\PythonProject\LogAnalysis\rawdata\LogOutput.csv"
df_log = pd.read_csv(path)
df_log_RA_MSG = df_log[df_log.MSG+df_log.RA>0]
df_CRNTI_RA_MSG = df_log_RA_MSG.groupby('CRNTI').size()

# %%
df_CRNTI = df_log.groupby('CRNTI').size()
crnticount = list(df_CRNTI)[1:]
sns.distplot(crnticount, rug=True)
# Out:
# D:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df_log[df_log.CRNTI=="20994"].to_excel("e:/wenpeiyu/pythonproject/loganalysis/rawdata/20994.xlsx")

# %%
df_log_RA_MSG.groupby("CRNTI")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-832d23633930> in <module>()
# ----> 1 df_log_RA_MSG.groupby("CRNTI")[20588]
#
# D:\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     265         else:
#     266             if key not in self.obj:
# --> 267                 raise KeyError("Column not found: {key}".format(key=key))
#     268             return self._gotitem(key, ndim=1)
#     269
#
# KeyError: 'Column not found: 20588'

# %%
def extract_dict_log(df_log):
    lst_CRNTI = list(set(df_log.CRNTI))
    dict_log = {i:df_log_RA_MSG[df_log_RA_MSG.CRNTI==i] for i in lst_CRNTI}
    return dict_log

# %%
lst_CRNTI = list(set(df_log_RA_MSG.CRNTI))
dict_log = {i:df_log_RA_MSG[df_log_RA_MSG.CRNTI==i] for i in lst_CRNTI}
df_20588 = dict_log['20588']
lst_index = list(df_20588.index)
df_20588["dd"] = [0]+[lst_index[i+1]-lst_index[i] for i in range(len(lst_index)-1)]
df_20588 = pd.DataFrame(df_20588)
lst_header = list(df_20588[df_20588.dd > 150000].index)
lst_header_extension = [-1] + lst_header + [9999999999]
lst_log_split = [df_20588[(df_20588.index>lst_header_extension[i])&(df_20588.index<lst_header_extension[i+1])] for i in range(len(lst_header)+1)]
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
# Out:
# 2

# %%
lst_log_split
# Out:
# [               DateTime  Sequence            LogSpace PriClass  interHSFN  \
#  129461  24-18:29:42:860    210108  Module:MAINFLOWLOG  Pri:FLW     238686
#  129462  24-18:29:42:860    210111  Module:MAINFLOWLOG  Pri:WRN     238686
#  129492  24-18:29:42:860    210201  Module:MAINFLOWLOG  Pri:FLW     238686
#  129493  24-18:29:42:860    210204  Module:MAINFLOWLOG  Pri:FLW     238686
#  129494  24-18:29:42:860    210207  Module:MAINFLOWLOG  Pri:FLW     238686
#  129498  24-18:29:42:860    210219  Module:MAINFLOWLOG  Pri:FLW     238686
#  129499  24-18:29:42:860    210222  Module:MAINFLOWLOG  Pri:INF     238686
#  129501  24-18:29:42:860    210228  Module:MAINFLOWLOG  Pri:FLW     238686
#  129502  24-18:29:42:860    210231  Module:MAINFLOWLOG  Pri:WRN     238686
#  129503  24-18:29:42:860    210234  Module:MAINFLOWLOG  Pri:WRN     238686
#  129862  24-18:29:42:900    211311  Module:MAINFLOWLOG  Pri:FLW     238686
# ...
